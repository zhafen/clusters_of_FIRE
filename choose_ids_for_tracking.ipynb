# %%
import h5py
import os

# %% [markdown]
# # Load ID Data

# %%
data_dir = '/scratch/03057/zhafen/linefinder_data/multiphysics/m12i_res7100_mhdcv/data'
file_name = 'ClusterPopulation_1_reduced.hdf5'
file_path = os.path.join( data_dir, file_name )
f = h5py.File( file_path, 'r' )

# %%
list( f.keys() )
# Out:
# ['Cloud',
#  'CloudClusterID',
#  'Coordinates',
#  'EFFGamma',
#  'FormationRedshift',
#  'FormationTime',
#  'GalactocentricMenc',
#  'GalactocentricRadius',
#  'HalfMassRadius',
#  'Mass',
#  'Metallicity',
#  'ProgenitorMass',
#  'ProgenitorReff',
#  'Snapshot',
#  'TracerID']

# %% [markdown]
# # Store ID Data

# %%
file_name = 'ids_full_m12imhdcv_clustersofFIRE_pop1.hdf5'
file_path = os.path.join( data_dir, file_name )
g = h5py.File( file_path, 'w' )

# %%
g.create_dataset( 'target_ids', data=f['TracerID'][...] )
# Out:
# <HDF5 dataset "target_ids": shape (73461,), type "<f8">

# %%
g.close()
f.close()

# %%
67025. / 73461.
# Out:
# 0.9123888866201113

# %%
import numpy as np

# %%
np.unique( f['TracerID'][...] ).size / f['TracerID'][...].size
# Out:
# 0.9126203019289146

# %%
67/74
# Out:
# 0.9054054054054054
